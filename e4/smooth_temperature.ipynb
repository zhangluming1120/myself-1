# %%
import pandas as pd
import numpy as np
import csv
import sys
import difflib as dl

# %%
myfile = open('movie_list.txt','r')
pd.read_fwf(myfile)
# Out:
#                       28 Days Later...
# 0                       A Time to Kill
# 1                            Anomalisa
# 2                 Central Intelligence
# 3                   Dead Poets Society
# 4                           Detachment
# 5                    Dial M for Murder
# 6                    Dog Day Afternoon
# 7                            El cuerpo
# 8                              Everest
# 9               Everybody Wants Some!!
# 10                        Garden State
# 11                   God Bless America
# 12                  Heaven Is for Real
# 13                    Hitman: Agent 47
# 14      House at the End of the Street
# 15              I Spit on Your Grave 2
# 16                        Intouchables
# 17                Jûsan-nin no shikaku
# 18                        Liberal Arts
# 19                       Love Actually
# 20                             Macbeth
# 21  Madagascar 3: Europe's Most Wanted
# 22                          Maleficent
# ...
